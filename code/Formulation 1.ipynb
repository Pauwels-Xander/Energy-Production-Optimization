# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# --- Define Data ---
demand_data = pd.read_excel('Realistic Data Demand.xlsx')
demand = demand_data['Demand'].tolist()
T = len(demand)  # 自动设置时间段数
generators = ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8']

min_uptime = {'G1': 168, 'G2': 24, 'G3': 24, 'G4': 12, 'G5': 8, 'G6': 8, 'G7': 0, 'G8': 0}
min_downtime = {'G1': 168, 'G2': 12, 'G3': 12, 'G4': 8, 'G5': 4, 'G6': 4, 'G7': 0, 'G8': 0}
initial_on_time = {'G1': 85, 'G2': 0, 'G3': 20, 'G4': 15, 'G5': 6, 'G6': 5, 'G7': 0, 'G8': 0}
initial_off_time = {'G1': 0, 'G2': 10, 'G3': 0, 'G4': 0, 'G5': 0, 'G6': 0, 'G7': 3, 'G8': 12}
min_capacity = {'G1': 240, 'G2': 235, 'G3': 210, 'G4': 32, 'G5': 480, 'G6': 195, 'G7': 0, 'G8': 0}
max_capacity = {'G1': 480, 'G2': 590, 'G3': 520, 'G4': 406, 'G5': 870, 'G6': 350, 'G7': 735, 'G8': 1410}
startup_cost = {'G1': 10380, 'G2': 33590, 'G3': 0, 'G4': 23420, 'G5': 0, 'G6': 0, 'G7': 0, 'G8': 0}
no_load_cost = {'G1': 0, 'G2': 530, 'G3': 490, 'G4': 395, 'G5': 830, 'G6': 255, 'G7': 0, 'G8': 0}
variable_cost = {'G1': 7.7, 'G2': 16.3, 'G3': 17, 'G4': 23.7, 'G5': 40, 'G6': 45, 'G7': 75, 'G8': 77}

lambda_penalty = 100  #

pRE = demand_data['Renewable Scenario 2'].tolist()
alpha = 0.5

# --- Create Gurobi Model ---
model = gp.Model('Unit Commitment Takriti 2000')

# --- Define Decision Variables ---
u = model.addVars(generators, range(1, T+1), vtype=GRB.BINARY, name='u')
p = model.addVars(generators, range(1, T+1), vtype=GRB.CONTINUOUS, name='p')
s = model.addVars(range(1, T+1), vtype=GRB.CONTINUOUS, name='s')
v = model.addVars(generators, range(1, T+1), vtype=GRB.BINARY, name='v')
# --- Set Objective Function ---
model.setObjective(
    gp.quicksum(no_load_cost[g] * u[g, t] + variable_cost[g] * p[g, t] + startup_cost[g] * v[g, t]
                for g in generators for t in range(1, T+1)) +
    lambda_penalty * gp.quicksum(s[t] for t in range(1, T+1)),
    GRB.MINIMIZE
)

# --- Add Constraints ---

# 1. Power Output Constraints
for g in generators:
    for t in range(1, T+1):
        model.addConstr(p[g, t] >= min_capacity[g] * u[g, t], name=f'min_cap_{g}_{t}')
        model.addConstr(p[g, t] <= max_capacity[g] * u[g, t], name=f'max_cap_{g}_{t}')

# 2. Demand Satisfaction
for t in range(1, T+1):
    model.addConstr(
        gp.quicksum(p[g, t] for g in generators) + alpha * pRE[t - 1] == demand[t - 1] + s[t],
        name=f'demand_{t}'
    )
    model.addConstr(s[t] >= 0, name=f's_nonneg_{t}')

# 3. Minimum Uptime Constraints
for g in generators:
    u_0 = 1 if initial_on_time[g] > 0 else 0
    # t=1
    s_max = min(min_uptime[g] - 1, T - 1)
    for ss in range(1, s_max + 1):
        model.addConstr(u[g, 1] - u_0 <= u[g, 1 + ss], name=f'min_up_{g}_1_{1+ss}')
    # t=2 到 T-1
    for t in range(2, T):
        s_max = min(min_uptime[g] - 1, T - t)
        for ss in range(1, s_max + 1):
            model.addConstr(u[g, t] - u[g, t-1] <= u[g, t + ss], name=f'min_up_{g}_{t}_{t+ss}')

# 4. Minimum Downtime Constraints
for g in generators:
    u_0 = 1 if initial_on_time[g] > 0 else 0
    # t=1
    s_max = min(min_downtime[g] - 1, T - 1)
    for ss in range(1, s_max + 1):
        model.addConstr(u_0 - u[g, 1] <= 1 - u[g, 1 + ss], name=f'min_down_{g}_1_{1+ss}')
    # t=2 到 T-1
    for t in range(2, T):
        s_max = min(min_downtime[g] - 1, T - t)
        for ss in range(1, s_max + 1):
            model.addConstr(u[g, t-1] - u[g, t] <= 1 - u[g, t + ss], name=f'min_down_{g}_{t}_{t+ss}')# 5. Startup Definition Constraints
for g in generators:
    # For t = 2, ..., T
    for t in range(2, T+1):
        model.addConstr(v[g, t] >= u[g, t] - u[g, t-1], name=f'start_def_{g}_{t}')
    # For t = 1, use initial status u_{i,0}
    u_prev = 1 if initial_on_time[g] > 0 else 0
    model.addConstr(v[g, 1] >= u[g, 1] - u_prev, name=f'start_def_{g}_1')

# 6. Initial Condition Constraints
for g in generators:
    # If u_{i,0} = 1 and U_1^i < L_i, enforce u_{i,t} = 1
    if initial_on_time[g] > 0 and initial_on_time[g] < min_uptime[g]:
        remaining_uptime = min_uptime[g] - initial_on_time[g]
        for t in range(1, min(remaining_uptime, T) + 1):
            model.addConstr(u[g, t] == 1, name=f'initial_on_{g}_{t}')
    # If u_{i,0} = 0 and U_0^i < l_i, enforce u_{i,t} = 0
    if initial_off_time[g] > 0 and initial_off_time[g] < min_downtime[g]:
        remaining_downtime = min_downtime[g] - initial_off_time[g]
        for t in range(1, min(remaining_downtime, T) + 1):
            model.addConstr(u[g, t] == 0, name=f'initial_off_{g}_{t}')

# --- Solve the Model ---
model.optimize()

# --- Output Results ---
if model.status == GRB.OPTIMAL:
    print(f"Optimal Total Cost: {model.objVal}")
    for t in range(1, T+1):
        print(f"\nTime Period {t}:")
        for g in generators:
            print(f"  Unit {g}: Status={u[g,t].x}, Power={p[g,t].x}, Start-up={v[g,t].x}")
        print(f"  Curtailed Energy: {s[t].x}")
else:
    print("No optimal solution found. Please check the model setup or data.")
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 49480 rows, 4200 columns and 145452 nonzeros
# Model fingerprint: 0xe83fceb5
# Variable types: 1512 continuous, 2688 integer (2688 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [8e+00, 3e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 32304 rows and 1665 columns
# Presolve time: 0.16s
# Presolved: 17176 rows, 2535 columns, 52195 nonzeros
# Variable types: 1296 continuous, 1239 integer (1239 binary)
# Found heuristic solution: objective 1.247278e+07
# Found heuristic solution: objective 1.216149e+07
# Root relaxation presolved: 12025 rows, 7686 columns, 41893 nonzeros
#
#
# Root relaxation: objective 9.122799e+06, 1609 iterations, 0.06 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9122799.40    0  247 1.2161e+07 9122799.40  25.0%     -    0s
# H    0     0                    1.207925e+07 9122799.40  24.5%     -    0s
# H    0     0                    9569366.2658 9122799.40  4.67%     -    0s
# H    0     0                    9424193.1127 9122799.40  3.20%     -    0s
#      0     0 9263629.42    0  210 9424193.11 9263629.42  1.70%     -    0s
# H    0     0                    9393510.1477 9263731.06  1.38%     -    0s
#      0     0 9270144.53    0  180 9393510.15 9270144.53  1.31%     -    0s
#      0     0 9270161.83    0  180 9393510.15 9270161.83  1.31%     -    0s
#      0     0 9309178.52    0  150 9393510.15 9309178.52  0.90%     -    0s
#      0     0 9312453.56    0  174 9393510.15 9312453.56  0.86%     -    0s
#      0     0 9313364.96    0  154 9393510.15 9313364.96  0.85%     -    0s
# H    0     0                    9383309.2587 9313364.96  0.75%     -    0s
# H    0     0                    9382079.2587 9313364.96  0.73%     -    0s
#      0     0 9328882.55    0   87 9382079.26 9328882.55  0.57%     -    0s
# H    0     0                    9380999.3244 9328931.58  0.56%     -    0s
#      0     0 9330468.62    0   65 9380999.32 9330468.62  0.54%     -    0s
#      0     0 9330622.64    0   65 9380999.32 9330622.64  0.54%     -    0s
#      0     0 9330655.18    0   65 9380999.32 9330655.18  0.54%     -    0s
#      0     0 9334567.26    0   69 9380999.32 9334567.26  0.49%     -    1s
# H    0     0                    9358564.6896 9334598.15  0.26%     -    1s
#      0     0 9335547.90    0   71 9358564.69 9335547.90  0.25%     -    1s
#      0     0 9335605.74    0   72 9358564.69 9335605.74  0.25%     -    1s
#      0     0 9335608.00    0   72 9358564.69 9335608.00  0.25%     -    1s
#      0     0 9337613.18    0   92 9358564.69 9337613.18  0.22%     -    1s
#      0     0 9338145.17    0   70 9358564.69 9338145.17  0.22%     -    1s
#      0     0 9338262.13    0   92 9358564.69 9338262.13  0.22%     -    1s
#      0     0 9338272.33    0   92 9358564.69 9338272.33  0.22%     -    1s
#      0     0 9338631.95    0   66 9358564.69 9338631.95  0.21%     -    1s
# H    0     0                    9356565.8271 9338669.73  0.19%     -    1s
#      0     0 9338769.31    0   67 9356565.83 9338769.31  0.19%     -    1s
#      0     0 9338808.37    0   66 9356565.83 9338808.37  0.19%     -    1s
#      0     0 9339450.77    0   68 9356565.83 9339450.77  0.18%     -    1s
#      0     0 9339450.77    0  243 9356565.83 9339450.77  0.18%     -    1s
#      0     0 9339450.77    0  179 9356565.83 9339450.77  0.18%     -    1s
#      0     0 9339450.77    0   66 9356565.83 9339450.77  0.18%     -    1s
#      0     0 9339450.77    0   32 9356565.83 9339450.77  0.18%     -    1s
#      0     0 9339562.17    0   30 9356565.83 9339562.17  0.18%     -    1s
#      0     0 9339837.54    0   62 9356565.83 9339837.54  0.18%     -    1s
#      0     0 9339966.19    0   58 9356565.83 9339966.19  0.18%     -    1s
# H    0     0                    9354308.5306 9339966.19  0.15%     -    1s
#      0     0 9340661.11    0   30 9354308.53 9340661.11  0.15%     -    1s
#      0     0 9340732.21    0   36 9354308.53 9340732.21  0.15%     -    1s
#      0     0 9342324.87    0   73 9354308.53 9342324.87  0.13%     -    1s
# H    0     0                    9353940.0674 9342423.37  0.12%     -    1s
#      0     0 9342423.37    0   74 9353940.07 9342423.37  0.12%     -    1s
#      0     0 9342464.59    0   74 9353940.07 9342464.59  0.12%     -    1s
#      0     0 9342639.29    0   30 9353940.07 9342639.29  0.12%     -    1s
# H    0     0                    9353718.2144 9342951.07  0.12%     -    1s
#      0     0 9342951.07    0   30 9353718.21 9342951.07  0.12%     -    1s
# H    0     0                    9351868.0926 9342951.07  0.10%     -    1s
#      0     0 9342951.07    0   73 9351868.09 9342951.07  0.10%     -    1s
#      0     0 9342951.07    0   72 9351868.09 9342951.07  0.10%     -    1s
#      0     0 9342951.07    0   30 9351868.09 9342951.07  0.10%     -    1s
#      0     0 9342951.07    0   30 9351868.09 9342951.07  0.10%     -    1s
#      0     0 9342951.07    0  164 9351868.09 9342951.07  0.10%     -    1s
#      0     0 9342951.07    0  121 9351868.09 9342951.07  0.10%     -    1s
#      0     0 9344643.34    0   84 9351868.09 9344643.34  0.08%     -    2s
#      0     0 9346265.33    0   32 9351868.09 9346265.33  0.06%     -    2s
#      0     0 9346379.79    0   37 9351868.09 9346379.79  0.06%     -    2s
#      0     0 9346432.52    0   32 9351868.09 9346432.52  0.06%     -    2s
#      0     0 9350853.53    0    4 9351868.09 9350853.53  0.01%     -    2s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 18
#   Implied bound: 49
#   Clique: 1
#   MIR: 93
#   StrongCG: 1
#   Flow cover: 32
#   Zero half: 1
#   RLT: 117
#   Relax-and-lift: 1
#   BQP: 4
#   PSD: 1
#
# Explored 1 nodes (8522 simplex iterations) in 2.03 seconds (3.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 9.35187e+06 9.35372e+06 9.35394e+06 ... 9.39351e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.351868092639e+06, best bound 9.351280769971e+06, gap 0.0063%
# Optimal Total Cost: 9351868.092639223
#
# Time Period 1:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=0.0, Power=0.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=216.1800000000003, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 2:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=0.0, Power=0.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=247.35, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 3:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=1.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=304.27, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 4:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=260.25999999999976, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 5:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=600.5100000000002, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 6:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=629.4610636714601, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 7:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=262.70932165577005, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 8:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=603.9494969452203, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 9:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=676.0390855390301, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 10:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=735.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=64.7104081259804, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 11:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=393.0865332408598, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 12:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=735.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=60.32182205261006, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 13:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=683.2851422582098, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 14:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=368.21271749592006, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 15:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=384.2279382756201, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 16:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=415.09207157525, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 17:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=513.0507897093603, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 18:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=605.66578013244, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 19:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=432.9223775574701, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 20:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=132.37074185099982, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 21:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=269.5560742584098, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 22:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=355.7595139825403, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 23:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=372.4999830029601, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 24:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=327.1570523297801, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 25:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=425.46000000000004, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 26:
#   Unit G1: Status=1.0, Power=440.8320000000001, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 27:
#   Unit G1: Status=1.0, Power=262.8520000000003, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 28:
#   Unit G1: Status=1.0, Power=428.62934979094007, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 29:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=222.76473226964004, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 30:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=344.27356878719, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 31:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=95.73455391972948, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 32:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=146.74696568051013, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 33:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=184.30674197249027, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 34:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=767.5050174491998, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 35:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=759.6607780180193, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 36:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=647.5704449893901, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 37:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=292.73241772841993, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 38:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=207.89254919326004, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 39:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=651.6960485211998, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 40:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=645.2335433571998, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 41:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=613.9667455708304, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 42:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=15.940224156749991, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 43:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=635.3885638187598, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 44:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=76.73728541016953, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 45:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=275.2088885660096, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 46:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=116.14401007051993, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 47:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=481.8788610555898, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 48:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=535.4872030506799, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 49:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=323.85, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 50:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=286.40999999999883, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 51:
#   Unit G1: Status=1.0, Power=441.26627135992, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 52:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=436.2275261141601, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 53:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=503.57776234772973, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 54:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=370.0458070180898, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 55:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=150.9756686436499, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 56:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=578.6555224617905, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 57:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=233.1216055964801, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 58:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=339.70465328375985, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 59:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=237.25435849436963, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 60:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=321.7862661392601, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 61:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=314.7448131916399, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 62:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=277.0677772546801, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 63:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=533.5733346674797, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 64:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=351.2399681637298, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 65:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=511.0838457405598, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 66:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=709.5350024107001, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 67:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=394.90177278712054, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 68:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=640.48434053456, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 69:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=374.0919262266798, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 70:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=225.92998271625947, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 71:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=67.11104459129001, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 72:
#   Unit G1: Status=1.0, Power=421.1175098324197, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 73:
#   Unit G1: Status=1.0, Power=245.46000000000004, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 74:
#   Unit G1: Status=1.0, Power=240.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 127.32000000000016
#
# Time Period 75:
#   Unit G1: Status=1.0, Power=240.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 119.08464343771993
#
# Time Period 76:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=260.94344190089885, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 77:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=312.0811789598299, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 78:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=364.40663068438016, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 79:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=385.2842010075801, Start-up=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 80:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=132.57288295781018, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 81:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0
#   Unit G5: Status=1.0, Power=675.7331767465503, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 82:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=610.4554381320504, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 83:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=372.7264338248401, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 84:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=182.24255609587, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 85:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=259.0603795249799, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 86:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=272.4232652836299, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 87:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=629.35635595241, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 88:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=708.4300819411501, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 89:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=94.32574451391974, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 90:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=821.0296118325896, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 91:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=602.3834834785298, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 92:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=747.07872183372, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 93:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=484.85147274460996, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 94:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=3.509015810439905, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 95:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=87.03947402682024, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 96:
# ...
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 133:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=147.5507327901796, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 134:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=270.0435084658402, Start-up=0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 135:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=744.4811539953798, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 136:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=573.02926688058, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 137:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=800.95046288911, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 138:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=84.73966903653957, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 139:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=733.9415152634297, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 140:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=855.7727425376797, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 141:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=575.5592183704703, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 142:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=200.44661592092984, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 143:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=344.4629502551202, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 144:
#   Unit G1: Status=1.0, Power=412.72045025655007, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 145:
#   Unit G1: Status=1.0, Power=240.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 265.84749999999985
#
# Time Period 146:
#   Unit G1: Status=1.0, Power=240.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 314.36699999999996
#
# Time Period 147:
#   Unit G1: Status=1.0, Power=240.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 297.4535000000001
#
# Time Period 148:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=435.41608804671, Start-up=0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 149:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=432.9074652874899, Start-up=1.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 150:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=290.3735550606698, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 151:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=344.70228129298994, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 152:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=139.75622684015025, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 153:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=390.5268143165199, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 154:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=653.3943011915499, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 155:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=735.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=123.25017274640959, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 156:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=353.09598592086013, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 157:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=430.98852462699006, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 158:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=352.44577486765, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 159:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=41.79235243611993, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 160:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=288.1061093420399, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 161:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=99.59664348682008, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 162:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=193.0159736027199, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 163:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=60.87057053804983, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 164:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=1.0, Power=741.3089692281201, Start-up=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 165:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=319.3788806777402, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 166:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=1.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=1.0, Power=230.84191780051015, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 167:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=0.0
#   Unit G3: Status=1.0, Power=397.02404538557994, Start-up=1.0
#   Unit G4: Status=-0.0, Power=0.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0
#
# Time Period 168:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0
#   Unit G2: Status=1.0, Power=432.45695255392025, Start-up=0.0
#   Unit G3: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G4: Status=-0.0, Power=0.0, Start-up=0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0
#   Curtailed Energy: 0.0

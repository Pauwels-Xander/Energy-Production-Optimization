# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# --- Define Data ---
demand_data = pd.read_excel('Realistic Data Demand.xlsx')
demand = demand_data['Demand'].tolist()
T = len(demand)  # 自动设置时间段数
generators = ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8']

min_uptime = {'G1': 168, 'G2': 24, 'G3': 24, 'G4': 12, 'G5': 8, 'G6': 8, 'G7': 0, 'G8': 0}
min_downtime = {'G1': 168, 'G2': 12, 'G3': 12, 'G4': 8, 'G5': 4, 'G6': 4, 'G7': 0, 'G8': 0}
initial_on_time = {'G1': 85, 'G2': 0, 'G3': 20, 'G4': 15, 'G5': 6, 'G6': 5, 'G7': 0, 'G8': 0}
initial_off_time = {'G1': 0, 'G2': 10, 'G3': 0, 'G4': 0, 'G5': 0, 'G6': 0, 'G7': 3, 'G8': 12}
min_capacity = {'G1': 240, 'G2': 235, 'G3': 210, 'G4': 32, 'G5': 480, 'G6': 195, 'G7': 0, 'G8': 0}
max_capacity = {'G1': 480, 'G2': 590, 'G3': 520, 'G4': 406, 'G5': 870, 'G6': 350, 'G7': 735, 'G8': 1410}
startup_cost = {'G1': 10380, 'G2': 33590, 'G3': 0, 'G4': 23420, 'G5': 0, 'G6': 0, 'G7': 0, 'G8': 0}
no_load_cost = {'G1': 0, 'G2': 530, 'G3': 490, 'G4': 395, 'G5': 830, 'G6': 255, 'G7': 0, 'G8': 0}
variable_cost = {'G1': 7.7, 'G2': 16.3, 'G3': 17, 'G4': 23.7, 'G5': 40, 'G6': 45, 'G7': 75, 'G8': 77}

lambda_penalty = 100  #

pRE = demand_data['Renewable Scenario 2'].tolist()
alpha = 0.5

# --- Create Gurobi Model ---
model = gp.Model('Unit Commitment')  # Model name: Unit Commitment

# --- Define Decision Variables ---
# u[g, t]: Binary variable indicating whether generator g is ON (1) or OFF (0) at time t
u = model.addVars(generators, range(1, T+1), vtype=GRB.BINARY, name='u')

# v[g, t]: Binary variable indicating whether generator g is started up at time t
v = model.addVars(generators, range(1, T+1), vtype=GRB.BINARY, name='v')

# w[g, t]: Binary variable indicating whether generator g is shut down at time t
w = model.addVars(generators, range(1, T+1), vtype=GRB.BINARY, name='w')

# p[g, t]: Continuous variable representing the power output of generator g at time t
p = model.addVars(generators, range(1, T+1), vtype=GRB.CONTINUOUS, name='p')

# s[t]: Continuous variable representing curtailed energy at time t 
s = model.addVars(range(1, T+1), vtype=GRB.CONTINUOUS, name='s')

# --- Set Objective Function ---
# The objective is to minimize the total cost, which includes:
# 1. No-load cost (fixed operation cost)
# 2. Variable generation cost
# 3. Start-up cost
# 4. Cost for curtailed energy (can be replaced with a penalty factor, lambda_penalty)
model.setObjective(
    gp.quicksum(no_load_cost[g] * u[g, t] + variable_cost[g] * p[g, t] + startup_cost[g] * v[g, t]
                for g in generators for t in range(1, T+1)) +
    lambda_penalty * gp.quicksum(s[t] for t in range(1, T+1)),
    GRB.MINIMIZE
)

# --- Add Constraints ---

# 1. Power Output Constraints: Ensure power output is within min and max capacity when the unit is on
for g in generators:
    for t in range(1, T+1):
        model.addConstr(p[g, t] >= min_capacity[g] * u[g, t], name=f'min_cap_{g}_{t}')
        model.addConstr(p[g, t] <= max_capacity[g] * u[g, t], name=f'max_cap_{g}_{t}')

# 2. Demand Satisfaction
for t in range(1, T+1):
    model.addConstr(
        gp.quicksum(p[g, t] for g in generators) + alpha * pRE[t - 1] == demand[t - 1] + s[t],
        name=f'demand_{t}'
    )
    model.addConstr(s[t] >= 0, name=f's_nonneg_{t}')
    
# 3. State Transition Constraints: Define how the unit status (on/off) changes over time
for g in generators:
    for t in range(1, T+1):
        if t == 1:
            # At time 1, the previous status is determined by initial_on_time or initial_off_time
            u_prev = 1 if initial_on_time[g] > 0 else 0
        else:
            # For other time periods, u[g, t-1] determines the previous status
            u_prev = u[g, t-1]
        model.addConstr(u[g, t] == u_prev + v[g, t] - w[g, t], name=f'state_transition_{g}_{t}')

# 4. Minimum Uptime Constraints: If a unit is started up, it must stay on for at least its minimum uptime
for g in generators:
    for t in range(1, T+1):
        min_up_end = min(t + min_uptime[g] - 1, T)
        for tau in range(t+1, min_up_end+1):
            model.addConstr(v[g, t] + w[g, tau] <= 1, name=f'min_up_{g}_{t}_{tau}')

# 5. Minimum Downtime Constraints: If a unit is shut down, it must stay off for at least its minimum downtime
for g in generators:
    for t in range(1, T+1):
        min_down_end = min(t + min_downtime[g] - 1, T)
        for tau in range(t+1, min_down_end+1):
            model.addConstr(w[g, t] + v[g, tau] <= 1, name=f'min_down_{g}_{t}_{tau}')

# 6. Initial Condition Constraints: Respect minimum uptime/downtime based on initial status
for g in generators:
    if initial_on_time[g] > 0 and initial_on_time[g] < min_uptime[g]:
        # Ensure the unit stays on to fulfill the remaining minimum uptime
        remaining_uptime = min_uptime[g] - initial_on_time[g]
        for t in range(1, min(remaining_uptime + 1, T+1)):
            model.addConstr(u[g, t] == 1, name=f'initial_on_{g}_{t}')
    elif initial_off_time[g] > 0 and initial_off_time[g] < min_downtime[g]:
        # Ensure the unit stays off to fulfill the remaining minimum downtime
        remaining_downtime = min_downtime[g] - initial_off_time[g]
        for t in range(1, min(remaining_downtime + 1, T+1)):
            model.addConstr(u[g, t] == 0, name=f'initial_off_{g}_{t}')

# --- Solve the Model ---
model.optimize()

# --- Output Results ---
if model.status == GRB.OPTIMAL:
    print(f"Optimal Total Cost: {model.objVal}")
    for t in range(1, T+1):
        print(f"\nTime Period {t}:")
        for g in generators:
            print(f"  Unit {g}: Status={u[g,t].x}, Power={p[g,t].x}, Start-up={v[g,t].x}, Shutdown={w[g,t].x}")
        print(f"  Curtailed Energy: {s[t].x}")
else:
    print("No optimal solution found. Please check the model setup or data.")
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 49480 rows, 5544 columns and 102218 nonzeros
# Model fingerprint: 0x84545c12
# Variable types: 1512 continuous, 4032 integer (4032 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [8e+00, 3e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 23932 rows and 1518 columns
# Presolve time: 0.21s
# Presolved: 25548 rows, 4026 columns, 62998 nonzeros
# Variable types: 1296 continuous, 2730 integer (2730 binary)
# Found heuristic solution: objective 1.358095e+07
# Found heuristic solution: objective 1.248507e+07
# Found heuristic solution: objective 1.247278e+07
# Root relaxation presolved: 25548 rows, 4026 columns, 62998 nonzeros
#
#
# Root relaxation: objective 8.936780e+06, 786 iterations, 0.03 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8936779.95    0  288 1.2473e+07 8936779.95  28.3%     -    0s
# H    0     0                    9519843.0640 8936779.95  6.12%     -    0s
# H    0     0                    9509463.0640 8936779.95  6.02%     -    0s
#      0     0 9054096.86    0  323 9509463.06 9054096.86  4.79%     -    0s
# H    0     0                    9438879.1067 9054325.40  4.07%     -    0s
#      0     0 9067475.40    0  307 9438879.11 9067475.40  3.93%     -    0s
#      0     0 9069014.88    0  297 9438879.11 9069014.88  3.92%     -    0s
#      0     0 9103248.19    0  249 9438879.11 9103248.19  3.56%     -    0s
#      0     0 9104371.80    0  250 9438879.11 9104371.80  3.54%     -    0s
# H    0     0                    9390949.3173 9104770.36  3.05%     -    0s
#      0     0 9104770.36    0  251 9390949.32 9104770.36  3.05%     -    0s
#      0     0 9104805.68    0  253 9390949.32 9104805.68  3.05%     -    0s
#      0     0 9104806.43    0  253 9390949.32 9104806.43  3.05%     -    0s
#      0     0 9124951.88    0  233 9390949.32 9124951.88  2.83%     -    0s
#      0     0 9125886.97    0  253 9390949.32 9125886.97  2.82%     -    0s
#      0     0 9126097.53    0  207 9390949.32 9126097.53  2.82%     -    0s
#      0     0 9126118.35    0  209 9390949.32 9126118.35  2.82%     -    0s
#      0     0 9133396.88    0  221 9390949.32 9133396.88  2.74%     -    0s
#      0     0 9134419.10    0  227 9390949.32 9134419.10  2.73%     -    0s
#      0     0 9134556.98    0  229 9390949.32 9134556.98  2.73%     -    0s
#      0     0 9134567.72    0  231 9390949.32 9134567.72  2.73%     -    0s
#      0     0 9136944.00    0  269 9390949.32 9136944.00  2.70%     -    0s
#      0     0 9137385.68    0  284 9390949.32 9137385.68  2.70%     -    0s
#      0     0 9137420.32    0  287 9390949.32 9137420.32  2.70%     -    0s
#      0     0 9137432.14    0  287 9390949.32 9137432.14  2.70%     -    0s
#      0     0 9142412.26    0  244 9390949.32 9142412.26  2.65%     -    0s
#      0     0 9143430.04    0  194 9390949.32 9143430.04  2.64%     -    0s
#      0     0 9143547.49    0  258 9390949.32 9143547.49  2.63%     -    1s
#      0     0 9143810.53    0  266 9390949.32 9143810.53  2.63%     -    1s
#      0     0 9143836.78    0  265 9390949.32 9143836.78  2.63%     -    1s
#      0     0 9145845.33    0  223 9390949.32 9145845.33  2.61%     -    1s
#      0     0 9146275.99    0  243 9390949.32 9146275.99  2.61%     -    1s
#      0     0 9146278.11    0  241 9390949.32 9146278.11  2.61%     -    1s
#      0     0 9148195.16    0  254 9390949.32 9148195.16  2.58%     -    1s
#      0     0 9148397.81    0  236 9390949.32 9148397.81  2.58%     -    1s
#      0     0 9148399.44    0  235 9390949.32 9148399.44  2.58%     -    1s
#      0     0 9149380.77    0  244 9390949.32 9149380.77  2.57%     -    1s
# H    0     0                    9382802.5569 9149714.07  2.48%     -    1s
# H    0     0                    9380588.5136 9150004.89  2.46%     -    1s
# H    0     0                    9375991.3777 9150004.89  2.41%     -    1s
#      0     0 9150004.89    0  234 9375991.38 9150004.89  2.41%     -    1s
#      0     0 9154494.38    0  251 9375991.38 9154494.38  2.36%     -    1s
#      0     0 9155176.71    0  229 9375991.38 9155176.71  2.36%     -    1s
# H    0     0                    9373079.8339 9155279.84  2.32%     -    1s
#      0     0 9155279.84    0  220 9373079.83 9155279.84  2.32%     -    1s
#      0     0 9155934.16    0  265 9373079.83 9155934.16  2.32%     -    1s
#      0     0 9156318.68    0  267 9373079.83 9156318.68  2.31%     -    1s
#      0     0 9156318.68    0  271 9373079.83 9156318.68  2.31%     -    1s
#      0     0 9156318.68    0  271 9373079.83 9156318.68  2.31%     -    1s
#      0     0 9156377.13    0  265 9373079.83 9156377.13  2.31%     -    1s
#      0     0 9156802.09    0  269 9373079.83 9156802.09  2.31%     -    1s
#      0     0 9157261.98    0  191 9373079.83 9157261.98  2.30%     -    1s
#      0     0 9157411.24    0  197 9373079.83 9157411.24  2.30%     -    1s
#      0     0 9157411.24    0  261 9373079.83 9157411.24  2.30%     -    1s
#      0     0 9158325.48    0  235 9373079.83 9158325.48  2.29%     -    1s
#      0     0 9158474.46    0  226 9373079.83 9158474.46  2.29%     -    1s
#      0     0 9158528.11    0  231 9373079.83 9158528.11  2.29%     -    1s
#      0     0 9158922.94    0  226 9373079.83 9158922.94  2.28%     -    1s
#      0     0 9159106.61    0  223 9373079.83 9159106.61  2.28%     -    1s
#      0     0 9159299.97    0  219 9373079.83 9159299.97  2.28%     -    1s
#      0     0 9159349.74    0  225 9373079.83 9159349.74  2.28%     -    1s
#      0     0 9159516.04    0  208 9373079.83 9159516.04  2.28%     -    1s
#      0     0 9159591.26    0  225 9373079.83 9159591.26  2.28%     -    1s
#      0     0 9159701.31    0  215 9373079.83 9159701.31  2.28%     -    1s
#      0     0 9159824.97    0  205 9373079.83 9159824.97  2.28%     -    1s
#      0     2 9160139.58    0  204 9373079.83 9160139.58  2.27%     -    1s
# H  134   123                    9372492.4071 9167482.07  2.19%  22.4    2s
# H  192   173                    9357947.5789 9167482.07  2.04%  22.8    2s
# H  242   199                    9354795.6406 9168836.84  1.99%  23.1    2s
# H  263   199                    9352935.3985 9169337.42  1.96%  22.6    2s
# H 1020   582                    9351925.6517 9182721.26  1.81%  21.7    2s
# H 1022   582                    9351868.0926 9182721.26  1.81%  21.7    2s
#   3206  1265 9223133.02    8  205 9351868.09 9199452.11  1.63%  23.7    6s
#   3252  1296 9264977.68   16  311 9351868.09 9264977.68  0.93%  23.4   10s
#
# Cutting planes:
#   Gomory: 14
#   Lift-and-project: 125
#   Cover: 16
#   Clique: 19
#   MIR: 141
#   Flow cover: 135
#   GUB cover: 75
#   Zero half: 65
#   Mod-K: 2
#   RLT: 74
#   Relax-and-lift: 12
#
# Explored 3588 nodes (96401 simplex iterations) in 13.24 seconds (24.97 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 9.35187e+06 9.35193e+06 9.35294e+06 ... 9.3828e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.351868092639e+06, best bound 9.351868092639e+06, gap 0.0000%
# Optimal Total Cost: 9351868.092639223
#
# Time Period 1:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=216.1800000000003, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=1.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 2:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=247.35, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 3:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=1.0, Shutdown=0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=304.27, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 4:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=260.25999999999976, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 5:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=600.5100000000002, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 6:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=629.4610636714601, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 7:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=262.70932165577005, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 8:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=603.9494969452203, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 9:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=676.0390855390301, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 10:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=735.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=64.7104081259804, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 11:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=393.0865332408598, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0, Shutdown=1.0
#   Curtailed Energy: 0.0
#
# Time Period 12:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=735.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=60.32182205261006, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 13:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=683.2851422582098, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0, Shutdown=1.0
#   Curtailed Energy: 0.0
#
# Time Period 14:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=368.21271749592006, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 15:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=384.2279382756201, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 16:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=415.09207157525, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 17:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=513.0507897093603, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 18:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=605.66578013244, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 19:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=432.9223775574701, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 20:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=132.37074185099982, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 21:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=269.5560742584098, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 22:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=355.7595139825403, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 23:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=372.4999830029601, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 24:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=327.1570523297801, Start-up=0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 25:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=425.46000000000004, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=-0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 26:
#   Unit G1: Status=1.0, Power=440.8320000000001, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 27:
#   Unit G1: Status=1.0, Power=262.8520000000003, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=-0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 28:
#   Unit G1: Status=1.0, Power=428.62934979094007, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 29:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=222.76473226964004, Start-up=0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 30:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=344.27356878719, Start-up=0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 31:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=95.73455391972948, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 32:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=146.74696568051013, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 33:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=184.30674197249027, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=1.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 34:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=767.5050174491998, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 35:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=759.6607780180193, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 36:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=647.5704449893899, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 37:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=292.73241772841993, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 38:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=207.89254919326004, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 39:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=651.6960485211998, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 40:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=645.2335433571998, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 41:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=613.9667455708304, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 42:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=15.940224156749991, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 43:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=635.3885638187598, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 44:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=76.73728541016953, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 45:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=275.2088885660096, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 46:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=116.14401007051993, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 47:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=481.8788610555898, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 48:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=535.4872030506799, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=-0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 49:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=323.85, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 50:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=286.40999999999985, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 51:
#   Unit G1: Status=1.0, Power=441.26627135992, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 52:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=436.2275261141601, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 53:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=503.57776234772973, Start-up=0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 54:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=370.0458070180898, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 55:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=150.9756686436499, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 56:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=578.6555224617905, Start-up=1.0, Shutdown=-0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 57:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=233.1216055964801, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 58:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=339.70465328375985, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 59:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=237.25435849436963, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 60:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=321.7862661392601, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 61:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=314.7448131916399, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 62:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=277.0677772546801, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 63:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=533.5733346674797, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=1.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 64:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=351.2399681637298, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 65:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=511.0838457405598, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 66:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=709.5350024107001, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 67:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=394.90177278712054, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 68:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=640.48434053456, Start-up=0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 69:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=374.0919262266798, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=1.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 70:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=225.92998271625947, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 71:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=67.11104459129001, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 72:
#   Unit G1: Status=1.0, Power=421.1175098324197, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=-0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 73:
#   Unit G1: Status=1.0, Power=245.46000000000004, Start-up=0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=-0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 74:
# ...
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 141:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=575.5592183704703, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 142:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=200.44661592092984, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=1.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 143:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=344.4629502551202, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 144:
#   Unit G1: Status=1.0, Power=412.72045025655007, Start-up=-0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=-0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 145:
#   Unit G1: Status=1.0, Power=240.0, Start-up=-0.0, Shutdown=0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 265.84749999999985
#
# Time Period 146:
#   Unit G1: Status=1.0, Power=240.0, Start-up=0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 314.36699999999996
#
# Time Period 147:
#   Unit G1: Status=1.0, Power=240.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=235.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 297.4535000000001
#
# Time Period 148:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=435.41608804671, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=210.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 149:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=432.9074652874899, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=32.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 150:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=290.3735550606698, Start-up=1.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 151:
#   Unit G1: Status=1.0, Power=480.0, Start-up=0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=1.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=344.70228129298994, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 152:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=139.75622684015025, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 153:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=390.5268143165199, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 154:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=653.3943011915499, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 155:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=735.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=123.25017274640959, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 156:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=353.09598592086013, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=1.0, Shutdown=1.0
#   Curtailed Energy: 0.0
#
# Time Period 157:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G7: Status=1.0, Power=430.98852462699006, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 158:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=352.44577486765, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 159:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=41.79235243611993, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 160:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=288.1061093420399, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 161:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=99.59664348682008, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 162:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=193.0159736027199, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 163:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=870.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=350.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=60.87057053804983, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 164:
#   Unit G1: Status=1.0, Power=479.99999999999955, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=1.0, Power=741.3089692281204, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=1.0, Power=195.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 165:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=1.0
#   Unit G6: Status=1.0, Power=319.3788806777402, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 166:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=520.0, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=1.0, Power=406.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=0.0, Power=0.0, Start-up=0.0, Shutdown=-0.0
#   Unit G6: Status=1.0, Power=230.84191780051015, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 167:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=590.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G3: Status=1.0, Power=397.02404538557994, Start-up=0.0, Shutdown=0.0
#   Unit G4: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=1.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=1.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
#
# Time Period 168:
#   Unit G1: Status=1.0, Power=480.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G2: Status=1.0, Power=432.4569525539202, Start-up=-0.0, Shutdown=0.0
#   Unit G3: Status=0.0, Power=0.0, Start-up=-0.0, Shutdown=1.0
#   Unit G4: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G5: Status=-0.0, Power=0.0, Start-up=-0.0, Shutdown=-0.0
#   Unit G6: Status=-0.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G7: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Unit G8: Status=1.0, Power=0.0, Start-up=0.0, Shutdown=0.0
#   Curtailed Energy: 0.0
